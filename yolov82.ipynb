# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.67-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.67-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.67 ultralytics-thop-2.0.20

# %%
import zipfile

with zipfile.ZipFile(
    "/content/Srintami-Transmission.v5i.yolov8.zip",
    'r'
) as zip_ref:
    zip_ref.extractall("/content/dataset-yolov8")

# %%
import yaml

base_dir = '/content/dataset-yolov8'

with open(f'{base_dir}/data.yaml', 'r') as f:
    data_config = yaml.safe_load(f)

data_config['train'] = f'{base_dir}/train/images'
data_config['val'] = f'{base_dir}/valid/images'
data_config['test'] = f'{base_dir}/test/images'

with open(f'{base_dir}/data.yaml', 'w') as f:
    yaml.dump(data_config, f, default_flow_style=False)

print("Updated data.yaml content:")
with open(f'{base_dir}/data.yaml', 'r') as f:
    print(f.read())
# Out:
# Updated data.yaml content:
# names:
# - aksesoris sisi cold
# - aksesoris sisi hot
# - arcing horn
# - bracing
# - insulator
# - jumper
# - pondasi
# nc: 7
# roboflow:
#   license: CC BY 4.0
#   project: srintami-transmission
#   url: https://universe.roboflow.com/diajengmahai-gmail-com/srintami-transmission/dataset/5
#   version: 5
#   workspace: diajengmahai-gmail-com
# test: /content/dataset-yolov8/test/images
# train: /content/dataset-yolov8/train/images
# val: /content/dataset-yolov8/valid/images

# %%
import os
import pandas as pd

def analyze_dataset_distribution(base_dir, dataset_type, class_names):
    label_dir = os.path.join(base_dir, dataset_type, 'labels')
    class_counts = {name: 0 for name in class_names}
    image_counts = {name: 0 for name in class_names}
    images_with_annotations = set()

    for label_file in os.listdir(label_dir):
        if label_file.endswith('.txt'):
            image_id = label_file.replace('.txt', '')
            has_annotation_for_image = False
            with open(os.path.join(label_dir, label_file), 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if parts:
                        class_idx = int(parts[0])
                        if 0 <= class_idx < len(class_names):
                            class_name = class_names[class_idx]
                            class_counts[class_name] += 1
                            has_annotation_for_image = True
            if has_annotation_for_image:
                images_with_annotations.add(image_id)

            with open(os.path.join(label_dir, label_file), 'r') as f:
                classes_in_image = set()
                for line in f:
                    parts = line.strip().split()
                    if parts:
                        class_idx = int(parts[0])
                        if 0 <= class_idx < len(class_names):
                            classes_in_image.add(class_names[class_idx])
                for class_name in classes_in_image:
                    image_counts[class_name] += 1

    return {
        'instance_counts': class_counts,
        'image_counts': image_counts,
        'total_images': len(os.listdir(os.path.join(base_dir, dataset_type, 'images'))),
        'total_instances': sum(class_counts.values())
    }

class_names = data_config['names']

train_stats = analyze_dataset_distribution(base_dir, 'train', class_names)
val_stats = analyze_dataset_distribution(base_dir, 'valid', class_names)
test_stats = analyze_dataset_distribution(base_dir, 'test', class_names)

# %%
data = {
    'Dataset': ['Train', 'Validation', 'Test'],
    'Image Count': [train_stats['total_images'], val_stats['total_images'], test_stats['total_images']],
    'Instance Count': [train_stats['total_instances'], val_stats['total_instances'], test_stats['total_instances']]
}
combined_counts_df = pd.DataFrame(data)

print("Combined Image and Instance Counts:")
display(combined_counts_df)
# Out:
# Combined Image and Instance Counts:
#       Dataset  Image Count  Instance Count
# 0       Train         1910            5705
# 1  Validation          409            1267
# 2        Test          409            1272

# %% [markdown]
# ### Detailed Distribution of Instances per Class

# %%
instance_distribution = {
    'Train': train_stats['instance_counts'],
    'Validation': val_stats['instance_counts'],
    'Test': test_stats['instance_counts']
}
distribution_df = pd.DataFrame(instance_distribution)

print("Detailed Instance Distribution per Class:")
display(distribution_df)
# Out:
# Detailed Instance Distribution per Class:
#                      Train  Validation  Test
# aksesoris sisi cold    495         111   118
# aksesoris sisi hot     704         148   143
# arcing horn           1032         236   267
# bracing                872         198   198
# insulator             1265         295   276
# jumper                 719         146   132
# pondasi                618         133   138

# %% [markdown]
# ### Detailed Distribution of Image per Class

# %%
image_distribution = {
    'Train': train_stats['image_counts'],
    'Validation': val_stats['image_counts'],
    'Test': test_stats['image_counts']
}
image_distribution_df = pd.DataFrame(image_distribution)

print("Detailed Image Distribution per Class:")
display(image_distribution_df)
# Out:
# Detailed Image Distribution per Class:
#                      Train  Validation  Test
# aksesoris sisi cold    388          93    91
# aksesoris sisi hot     484          91   100
# arcing horn            643         145   158
# bracing                785         183   178
# insulator              727         162   155
# jumper                 527         112   101
# pondasi                420          91    98

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/dataset-yolov8/data.yaml",
    epochs=150,
    imgsz=640,
    batch=16,
    augment=True,
    patience=30
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 107.9MB/s 0.1s
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset-yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 23.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752677  ultralytics.nn.modules.head.Detect           [7, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,213 parameters, 3,012,197 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 103.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 938.6±567.0 MB/s, size: 43.2 KB)
# train: Scanning /content/dataset-yolov8/train/labels... 1910 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1910/1910 2.2Kit/s 0.9s
# train: New cache created: /content/dataset-yolov8/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 819.6±678.9 MB/s, size: 45.2 KB)
# val: Scanning /content/dataset-yolov8/valid/labels... 409 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 409/409 1.2Kit/s 0.3s
# val: New cache created: /content/dataset-yolov8/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      2.06G      1.693      3.098       1.64         41        640: 100% ━━━━━━━━━━━━ 120/120 3.5it/s 33.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.4it/s 5.5s
#                    all        409       1267      0.499      0.362      0.347      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      2.56G      1.559      2.204       1.55         37        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        409       1267      0.643      0.378      0.379      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      2.56G      1.569      2.039      1.543         21        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.3s
#                    all        409       1267      0.501       0.48      0.459      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      2.56G      1.535       1.89      1.538         33        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.8it/s 4.6s
#                    all        409       1267       0.48      0.476      0.442      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      2.56G      1.505      1.803       1.51         34        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.4s
#                    all        409       1267      0.603      0.539      0.552      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150      2.56G      1.479      1.715      1.486         36        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.7s
#                    all        409       1267      0.582      0.547       0.55      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      2.56G       1.45      1.661      1.455         35        640: 100% ━━━━━━━━━━━━ 120/120 4.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        409       1267      0.579      0.529      0.552      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/150      2.56G      1.428      1.576      1.451         24        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.3s
#                    all        409       1267      0.676      0.536      0.597      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150      2.56G      1.433      1.568      1.446         27        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.1it/s 4.2s
#                    all        409       1267      0.648      0.595      0.635      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150      2.56G      1.387      1.484      1.414         33        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.673      0.587      0.642      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150      2.56G      1.391      1.475      1.415         27        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.654        0.6       0.64      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150      2.56G      1.373      1.437      1.401         36        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.8it/s 4.7s
#                    all        409       1267      0.617      0.634      0.632      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150      2.56G      1.351      1.394      1.382         41        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.4s
#                    all        409       1267      0.633      0.636      0.668      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      2.56G      1.327      1.335      1.359         35        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.682      0.658      0.681      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150      2.56G      1.349      1.374      1.387         41        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.9it/s 4.5s
#                    all        409       1267      0.681      0.629      0.683      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150      2.56G      1.312      1.336      1.363         24        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.647      0.639      0.668      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/150      2.56G      1.312      1.323      1.354         53        640: 100% ━━━━━━━━━━━━ 120/120 3.7it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.698      0.625      0.697      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/150      2.56G      1.315       1.29      1.349         29        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.3s
#                    all        409       1267      0.691      0.649       0.69      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/150      2.56G      1.283      1.257      1.334         37        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s
#                    all        409       1267      0.724      0.668      0.706      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/150      2.56G      1.302      1.284      1.345         30        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        409       1267      0.677      0.683      0.701      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/150      2.56G      1.287      1.247      1.332         33        640: 100% ━━━━━━━━━━━━ 120/120 3.6it/s 32.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.7it/s 4.8s
#                    all        409       1267      0.674      0.665      0.708      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/150      2.56G       1.26      1.231      1.322         30        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.729       0.63       0.71      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/150      2.56G      1.277      1.218      1.319         30        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.736      0.669      0.731      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/150      2.56G      1.267      1.215      1.324         43        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.3it/s 3.9s
#                    all        409       1267       0.73      0.648       0.72      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/150      2.56G      1.247      1.203      1.308         39        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.3s
#                    all        409       1267      0.745      0.649      0.718      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/150      2.56G      1.248      1.181      1.295         37        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.7it/s 4.8s
#                    all        409       1267      0.739      0.672      0.728      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/150      2.56G      1.242      1.182      1.299         29        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.3s
#                    all        409       1267      0.743      0.655      0.733       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/150      2.56G      1.236      1.163      1.296         31        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.3s
#                    all        409       1267      0.695      0.693      0.723       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/150      2.56G      1.238      1.141      1.294         26        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.2it/s 4.1s
#                    all        409       1267      0.711      0.706      0.748      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/150      2.56G      1.238      1.137      1.294         28        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.729      0.674      0.745       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/150      2.56G      1.219       1.13      1.283         32        640: 100% ━━━━━━━━━━━━ 120/120 3.7it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        409       1267      0.715      0.687      0.735      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/150      2.56G      1.205      1.103      1.274         41        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.4s
#                    all        409       1267      0.756      0.673      0.751      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/150      2.56G      1.191        1.1      1.269         24        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s
#                    all        409       1267      0.733       0.71      0.753      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/150      2.56G      1.182       1.08      1.263         29        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.714      0.713      0.737      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/150      2.56G       1.18      1.077      1.261         41        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.8it/s 4.7s
#                    all        409       1267      0.757      0.705      0.774      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/150      2.56G      1.197      1.076      1.258         31        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.3s
#                    all        409       1267      0.752      0.679      0.753      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/150      2.56G      1.174      1.072      1.251         28        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.747      0.705      0.766      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/150      2.56G       1.17      1.062       1.25         50        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.3it/s 3.9s
#                    all        409       1267      0.727      0.712      0.767       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/150      2.56G      1.181      1.048      1.254         47        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 31.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.3s
#                    all        409       1267      0.761      0.694      0.769      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/150      2.56G      1.171      1.062      1.257         37        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.719        0.7      0.745      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/150      2.56G      1.161      1.037      1.241         28        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.763      0.694      0.761      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/150      2.56G      1.151      1.014      1.236         56        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.4s
#                    all        409       1267      0.737      0.706      0.754       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/150      2.56G      1.145      1.006      1.231         50        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.8it/s 4.6s
#                    all        409       1267      0.798      0.646      0.748      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/150      2.56G      1.143      1.018      1.227         47        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.4s
#                    all        409       1267      0.745      0.701      0.755      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/150      2.56G      1.144      1.008      1.228         33        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.6s
#                    all        409       1267      0.737      0.722      0.767      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/150      2.56G      1.133     0.9995      1.225         42        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.4s
#                    all        409       1267      0.748      0.718      0.766      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/150      2.56G      1.109     0.9783      1.216         24        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.3s
#                    all        409       1267      0.776      0.719      0.774      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/150      2.56G      1.125     0.9961      1.219         31        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s
#                    all        409       1267      0.747      0.715      0.758      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/150      2.56G      1.127     0.9756      1.219         45        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.771      0.702       0.77       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/150      2.56G      1.118     0.9724      1.219         55        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267       0.74      0.732      0.772      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/150      2.56G      1.115     0.9788      1.209         27        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.7it/s 4.8s
#                    all        409       1267       0.78      0.686      0.771      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/150      2.56G      1.106     0.9457      1.216         32        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.748      0.743      0.779      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/150      2.56G        1.1     0.9389      1.201         49        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 32.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.3s
#                    all        409       1267      0.764      0.686      0.756      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/150      2.56G      1.103     0.9349      1.195         34        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.3s
#                    all        409       1267      0.768      0.714      0.773       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/150      2.56G      1.106     0.9534        1.2         24        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.787       0.69      0.769      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/150      2.56G      1.095     0.9309      1.195         67        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.778      0.705      0.775      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/150      2.56G      1.088     0.9081      1.199         28        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.2it/s 4.1s
#                    all        409       1267      0.747      0.741       0.78       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/150      2.56G      1.086     0.9138      1.193         26        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s
#                    all        409       1267      0.766      0.712       0.77      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/150      2.56G      1.092     0.9279      1.199         26        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.1it/s 4.1s
#                    all        409       1267      0.802      0.676      0.769      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/150      2.56G      1.096     0.9128      1.201         35        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s
#                    all        409       1267      0.806      0.691      0.776      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/150      2.56G       1.08     0.9023      1.197         47        640: 100% ━━━━━━━━━━━━ 120/120 3.7it/s 32.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.744      0.733      0.773      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/150      2.56G      1.068     0.9011      1.183         32        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.9it/s 4.6s
#                    all        409       1267      0.771      0.717       0.76      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/150      2.56G      1.069     0.8877      1.185         37        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s
#                    all        409       1267      0.774      0.708      0.761      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/150      2.56G       1.05       0.86       1.17         47        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        409       1267      0.803      0.689      0.776      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/150      2.56G      1.067     0.8856       1.18         35        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.4s
#                    all        409       1267      0.749      0.721      0.764      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/150      2.56G      1.045     0.8652      1.169         31        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.757      0.738       0.78      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/150      2.56G      1.066     0.8636      1.177         32        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        409       1267      0.788      0.715      0.774      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/150      2.56G       1.04     0.8588      1.166         57        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.774      0.726      0.782      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/150      2.56G      1.037     0.8402      1.162         32        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.2it/s 3.1s
#                    all        409       1267      0.753      0.733      0.772      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/150      2.56G      1.034     0.8383      1.161         37        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.7it/s 4.8s
#                    all        409       1267       0.78      0.707      0.766      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/150      2.56G      1.039     0.8571      1.167         45        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.1it/s 3.2s
#                    all        409       1267      0.737      0.746      0.773      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/150      2.56G      1.042       0.85      1.162         57        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 31.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.779      0.712      0.778      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/150      2.56G      1.028     0.8251      1.159         52        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.3s
#                    all        409       1267      0.789      0.717       0.78      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/150      2.56G      1.016     0.8267      1.156         23        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.743      0.748      0.772      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/150      2.56G      1.034     0.8357      1.163         29        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.3s
#                    all        409       1267      0.791      0.698      0.769      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/150      2.56G      1.029     0.8325      1.159         31        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s
#                    all        409       1267      0.745      0.732      0.776      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/150      2.56G      1.014     0.8117      1.156         21        640: 100% ━━━━━━━━━━━━ 120/120 3.7it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.2s
#                    all        409       1267       0.79        0.7       0.77      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/150      2.56G      1.018     0.8112      1.146         36        640: 100% ━━━━━━━━━━━━ 120/120 3.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.8it/s 4.6s
#                    all        409       1267      0.765      0.717      0.776      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/150      2.56G      1.004     0.8172      1.141         23        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.4s
#                    all        409       1267      0.744      0.743      0.778      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/150      2.56G      1.012     0.8124      1.153         46        640: 100% ━━━━━━━━━━━━ 120/120 3.8it/s 31.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.9it/s 3.3s
#                    all        409       1267      0.746      0.739      0.768      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/150      2.56G      1.009     0.8019      1.152         18        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.8it/s 4.7s
#                    all        409       1267      0.776      0.696      0.765       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/150      2.56G          1     0.8069       1.14         37        640: 100% ━━━━━━━━━━━━ 120/120 4.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.0it/s 3.2s
#                    all        409       1267      0.774      0.717      0.767      0.443
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 52, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 82 epochs completed in 0.797 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 6.2MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.7it/s 7.4s
#                    all        409       1267      0.748      0.733      0.785      0.467
#    aksesoris sisi cold         93        111      0.753      0.712      0.799      0.469
#     aksesoris sisi hot         91        148      0.798      0.791      0.831      0.445
#            arcing horn        145        236      0.752      0.743      0.822      0.493
#                bracing        183        198      0.592      0.771      0.734      0.506
#              insulator        162        295      0.766      0.723      0.799      0.593
#                 jumper        112        146      0.769      0.555      0.648      0.258
#                pondasi         91        133      0.805      0.837      0.861      0.503
# Speed: 0.2ms preprocess, 13.4ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/detect/train
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3, 4, 5, 6])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7a5fe0a04d70>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
# ...
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[   0.041059,    0.041059,    0.058788, ...,           1,           1,           1],
#        [   0.039665,    0.039665,    0.056738, ...,           1,           1,           1],
#        [   0.036715,    0.036715,    0.053289, ...,           1,           1,           1],
#        ...,
#        [   0.051563,    0.051563,    0.081672, ...,           1,           1,           1],
#        [   0.016616,    0.016616,    0.024015, ...,           1,           1,           1],
#        [    0.02831,     0.02831,    0.043847, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.96396,     0.96396,     0.96396, ...,           0,           0,           0],
#        [    0.95946,     0.95946,      0.9527, ...,           0,           0,           0],
#        [    0.98305,     0.98305,     0.97458, ...,           0,           0,           0],
#        ...,
#        [    0.95593,     0.95593,     0.94576, ...,           0,           0,           0],
#        [    0.94521,     0.94521,     0.93151, ...,           0,           0,           0],
#        [    0.97744,     0.97744,     0.96992, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: 0.466718662869491
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.46896,      0.4451,     0.49286,     0.50638,     0.59306,     0.25794,     0.50273])
# names: {0: 'aksesoris sisi cold', 1: 'aksesoris sisi hot', 2: 'arcing horn', 3: 'bracing', 4: 'insulator', 5: 'jumper', 6: 'pondasi'}
# nt_per_class: array([111, 148, 236, 198, 295, 146, 133])
# nt_per_image: array([ 93,  91, 145, 183, 162, 112,  91])
# results_dict: {'metrics/precision(B)': 0.7477655389661801, 'metrics/recall(B)': 0.7330407411469715, 'metrics/mAP50(B)': 0.7848617405410258, 'metrics/mAP50-95(B)': 0.466718662869491, 'fitness': 0.466718662869491}
# save_dir: PosixPath('/content/runs/detect/train')
# speed: {'preprocess': 0.1541131687034841, 'inference': 13.438780623471887, 'loss': 0.00038584107697829217, 'postprocess': 1.2892548484115742}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

results_path = '/content/runs/detect/train/results.csv'

if os.path.exists(results_path):
    results_df = pd.read_csv(results_path)

    results_df.columns = results_df.columns.str.strip()

    print("Hasil pelatihan (5 baris terakhir):")
    display(results_df.tail())

    plt.figure(figsize=(12, 6))
    plt.plot(results_df['epoch'], results_df['metrics/mAP50(B)'], label='mAP50(B)')
    plt.plot(results_df['epoch'], results_df['metrics/mAP50-95(B)'], label='mAP50-95(B)')
    plt.title('mAP50(B) and mAP50-95(B) Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('mAP Value')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print(f"File hasil pelatihan tidak ditemukan di: {results_path}")
    print("Pastikan model telah selesai melatih dan menyimpan hasilnya.")
# Out:
# Hasil pelatihan (5 baris terakhir):
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 77     78  2729.20         1.01804         0.81118         1.14634
# 78     79  2763.32         1.00404         0.81717         1.14058
# 79     80  2798.52         1.01216         0.81242         1.15297
# 80     81  2833.55         1.00856         0.80187         1.15172
# 81     82  2867.29         1.00004         0.80692         1.14014
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 77               0.76511            0.71690           0.77554
# 78               0.74375            0.74285           0.77789
# 79               0.74554            0.73872           0.76785
# 80               0.77601            0.69625           0.76500
# 81               0.77427            0.71687           0.76736
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 77              0.44919       1.34758       0.98051       1.33642  0.000447
# 78              0.45599       1.33208       0.98429       1.33388  0.000441
# 79              0.44922       1.33317       0.97216       1.32870  0.000435
# 80              0.44963       1.35150       0.98697       1.33895  0.000429
# 81              0.44273       1.35749       0.98041       1.35169  0.000423
#
#       lr/pg1    lr/pg2
# 77  0.000447  0.000447
# 78  0.000441  0.000441
# 79  0.000435  0.000435
# 80  0.000429  0.000429
# 81  0.000423  0.000423

# %%
model.predict(
    source="/content/insulator4.jpg",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 /content/insulator4.jpg: 480x640 2 bracings, 2 insulators, 64.5ms
# Speed: 4.9ms preprocess, 64.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'arching horn', 1: 'bracing', 2: 'insulator', 3: 'kabel'}
#  obb: None
#  orig_img: array([[[252, 247, 238],
#          [252, 247, 238],
#          [250, 248, 238],
#          ...,
#          [218, 213, 204],
#          [218, 213, 204],
#          [218, 213, 204]],
#
#         [[251, 246, 237],
#          [252, 247, 238],
#          [251, 249, 239],
#          ...,
#          [218, 213, 204],
#          [218, 213, 204],
#          [218, 213, 204]],
#
#         [[251, 246, 237],
#          [252, 247, 238],
#          [251, 249, 239],
#          ...,
#          [218, 213, 204],
#          [218, 213, 204],
#          [218, 213, 204]],
#
#         ...,
#
#         [[240, 240, 234],
#          [230, 230, 224],
#          [214, 216, 210],
#          ...,
#          [192, 187, 178],
#          [192, 187, 178],
#          [192, 187, 178]],
#
#         [[240, 240, 234],
#          [228, 228, 222],
#          [210, 212, 206],
#          ...,
#          [192, 187, 178],
#          [192, 187, 178],
#          [192, 187, 178]],
#
#         [[240, 240, 234],
#          [227, 227, 221],
#          [206, 208, 202],
#          ...,
#          [192, 187, 178],
#          [192, 187, 178],
#          [192, 187, 178]]], dtype=uint8)
#  orig_shape: (3000, 4000)
#  path: '/content/insulator4.jpg'
#  probs: None
#  save_dir: '/content/runs/detect/predict'
#  semantic_mask: None
#  speed: {'preprocess': 4.902663999928336, 'inference': 64.51160599999639, 'postprocess': 1.9046140000682499}]

# %%
from IPython.display import Image
import os

results = model.predict(
    source="/content/jumper.jpg",
    save=True,
    conf=0.25
)

save_dir = results[0].save_dir if results and hasattr(results[0], 'save_dir') else '/content/runs/detect/predict'

predicted_image_name = os.path.basename('/content/jumper.jpg')
predicted_image_path = os.path.join(save_dir, predicted_image_name)

if os.path.exists(predicted_image_path):
    display(Image(filename=predicted_image_path))
else:
    print(f"Gambar hasil deteksi tidak ditemukan di: {predicted_image_path}")
    print("Pastikan model.predict berjalan dan menyimpan hasilnya dengan benar.")
# Out:
# image 1/1 /content/jumper.jpg: 480x640 1 bracing, 1 jumper, 9.6ms
# Speed: 4.2ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict

# %%
import shutil
import os

source_path = '/content/runs/detect/train/weights/best.pt'

destination_path = '/content/best.pt'

if os.path.exists(source_path):
    shutil.copy(source_path, destination_path)
    print(f"Model \'{os.path.basename(source_path)}\' berhasil disalin ke \'{destination_path}\'")
    print("Anda sekarang bisa mengunduh file ini dari panel File di sebelah kiri Colab.")
else:
    print(f"File \'{source_path}\' tidak ditemukan. Pastikan pelatihan telah selesai dan menghasilkan file best.pt.")
# Out:
# Model 'best.pt' berhasil disalin ke '/content/best.pt'
# Anda sekarang bisa mengunduh file ini dari panel File di sebelah kiri Colab.
